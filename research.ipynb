# %%
import gc
import json
import optuna
import pandas as pd
import numpy as np
import xgboost as xgb

from pathlib import Path
from numerapi import NumerAPI
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

from helper import print_both, categorical_encoded

napi = NumerAPI()
current_round = napi.get_current_round()

# %%
# Tournament data changes every week so we specify the round in their name. Training
# and validation data only change periodically, so no need to download them every time.
print('Downloading dataset files...')

Path("./v4").mkdir(parents=False, exist_ok=True)
napi.download_dataset("v4/train.parquet")
napi.download_dataset("v4/validation.parquet")
napi.download_dataset("v4/live.parquet", f"v4/live_{current_round}.parquet")
napi.download_dataset("v4/validation_example_preds.parquet")
napi.download_dataset("v4/features.json")

# %%
ERA_COL = "era"
TARGET_COL = "target_nomi_v4_20"
DATA_TYPE_COL = "data_type"
EXAMPLE_PREDS_COL = "example_preds"

print('Reading minimal training data')
with open("v4/features.json", "r") as f:
    feature_metadata = json.load(f)

features = feature_metadata["feature_sets"]["medium"]
read_columns = features + [ERA_COL, DATA_TYPE_COL, TARGET_COL]
# Out:
# Reading minimal training data

# %%
training_data = pd.read_parquet('v4/train.parquet', columns=read_columns)
#training_data = training_data.replace([np.inf, -np.inf], np.nan)
training_data = categorical_encoded(training_data)


validation_data = pd.read_parquet('v4/validation.parquet', columns=read_columns)
#validation_data = validation_data.replace([np.inf, -np.inf], np.nan)

# %%
training_data = categorical_encoded(training_data)

target = TARGET_COL

data = training_data.copy()
optuna_target = data[target]
# Out:
# Names of categorical columns :  ['era', 'data_type']

# %%
train_x, test_x, train_y, test_y = train_test_split(data, optuna_target, test_size=0.2, random_state=42)

# %%
file = open(f'{current_round}_report.txt', 'w', encoding="utf-8")

def objective(trial):
    param = {
            'tree_method':'hist',  #this parameter means using the GPU when training our model to speedup the training process
            'n_estimators': trial.suggest_categorical('n_estimators', [300, 700]),
            'objective': trial.suggest_categorical('objective', ['reg:squarederror']),
            'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0, 5),
            'gamma': trial.suggest_float('gamma', 0, 5),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.0, 1.0),
            'subsample': trial.suggest_float('subsample', 0.0, 1.0),
            'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1),
            'max_depth': trial.suggest_int('max_depth', 3, 5),
            'random_state': trial.suggest_categorical('random_state', [2020]),
            'min_child_weight': trial.suggest_int('min_child_weight', 10, 300),
            'eval_metric': trial.suggest_categorical('eval_metric', ['mae'])
            }

    
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, 'validation_0-mae')
    model = xgb.XGBRegressor(**param)  
    
    model.fit(train_x, train_y, eval_set=[(test_x, test_y)], early_stopping_rounds=20, callbacks=[pruning_callback])
    
    preds = model.predict(test_x)
    
    mae = mean_absolute_error(test_y, preds)
    
    return mae

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=20, show_progress_bar=True)
print_both(file, 'Number of finished trials:', len(study.trials))
print_both(file, 'Best trial:', study.best_trial.params)

gc.collect()
# Out:
# [I 2022-11-28 10:58:59,172] A new study created in memory with name: no-name-0289c8f7-6519-473b-adc2-2813a8d6514b
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\progress_bar.py:49: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/20 [00:00<?, ?it/s]
# [0]	validation_0-mae:0.14999
# [1]	validation_0-mae:0.14409
# [2]	validation_0-mae:0.13842
# [3]	validation_0-mae:0.13851
# [4]	validation_0-mae:0.13306
# [5]	validation_0-mae:0.12783
# [6]	validation_0-mae:0.12280
# [7]	validation_0-mae:0.11798
# [8]	validation_0-mae:0.11799
# [9]	validation_0-mae:0.11336
# [10]	validation_0-mae:0.10890
# [11]	validation_0-mae:0.10462
# [12]	validation_0-mae:0.10051
# [13]	validation_0-mae:0.10056
# [14]	validation_0-mae:0.09661
# [15]	validation_0-mae:0.09282
# [16]	validation_0-mae:0.08917
# [17]	validation_0-mae:0.08922
# [18]	validation_0-mae:0.08925
# [19]	validation_0-mae:0.08929
# [20]	validation_0-mae:0.08579
# [21]	validation_0-mae:0.08243
# [22]	validation_0-mae:0.07920
# [23]	validation_0-mae:0.07610
# [24]	validation_0-mae:0.07312
# [25]	validation_0-mae:0.07314
# [26]	validation_0-mae:0.07028
# [27]	validation_0-mae:0.07030
# [28]	validation_0-mae:0.07032
# [29]	validation_0-mae:0.07035
# [30]	validation_0-mae:0.07035
# [31]	validation_0-mae:0.07037
# [32]	validation_0-mae:0.06762
# [33]	validation_0-mae:0.06762
# [34]	validation_0-mae:0.06498
# [35]	validation_0-mae:0.06244
# [36]	validation_0-mae:0.06000
# [37]	validation_0-mae:0.05766
# [38]	validation_0-mae:0.05541
# [39]	validation_0-mae:0.05325
# [40]	validation_0-mae:0.05117
# [41]	validation_0-mae:0.05117
# [42]	validation_0-mae:0.04918
# [43]	validation_0-mae:0.04918
# [44]	validation_0-mae:0.04726
# [45]	validation_0-mae:0.04542
# [46]	validation_0-mae:0.04365
# [47]	validation_0-mae:0.04195
# [48]	validation_0-mae:0.04032
# [49]	validation_0-mae:0.03875
# [50]	validation_0-mae:0.03725
# [51]	validation_0-mae:0.03580
# [52]	validation_0-mae:0.03441
# [53]	validation_0-mae:0.03441
# [54]	validation_0-mae:0.03441
# [55]	validation_0-mae:0.03441
# [56]	validation_0-mae:0.03308
# [57]	validation_0-mae:0.03180
# [58]	validation_0-mae:0.03180
# [59]	validation_0-mae:0.03180
# [60]	validation_0-mae:0.03056
# [61]	validation_0-mae:0.03056
# [62]	validation_0-mae:0.03056
# [63]	validation_0-mae:0.02938
# [64]	validation_0-mae:0.02938
# [65]	validation_0-mae:0.02824
# [66]	validation_0-mae:0.02715
# [67]	validation_0-mae:0.02715
# [68]	validation_0-mae:0.02715
# [69]	validation_0-mae:0.02610
# [70]	validation_0-mae:0.02610
# [71]	validation_0-mae:0.02610
# [72]	validation_0-mae:0.02610
# [73]	validation_0-mae:0.02610
# [74]	validation_0-mae:0.02510
# [75]	validation_0-mae:0.02413
# [76]	validation_0-mae:0.02320
# [77]	validation_0-mae:0.02230
# [78]	validation_0-mae:0.02230
# [79]	validation_0-mae:0.02145
# [80]	validation_0-mae:0.02145
# [81]	validation_0-mae:0.02145
# [82]	validation_0-mae:0.02145
# [83]	validation_0-mae:0.02145
# [84]	validation_0-mae:0.02062
# [85]	validation_0-mae:0.01983
# [86]	validation_0-mae:0.01983
# [87]	validation_0-mae:0.01907
# [88]	validation_0-mae:0.01907
# [195]	validation_0-mae:0.05292
# [196]	validation_0-mae:0.05258
# [197]	validation_0-mae:0.05223
# [198]	validation_0-mae:0.05189
# [199]	validation_0-mae:0.05155
# [200]	validation_0-mae:0.05155
# [201]	validation_0-mae:0.05155
# [202]	validation_0-mae:0.05122
# [203]	validation_0-mae:0.05088
# [204]	validation_0-mae:0.05055
# [205]	validation_0-mae:0.05055
# [206]	validation_0-mae:0.05022
# [207]	validation_0-mae:0.04989
# [208]	validation_0-mae:0.04989
# [209]	validation_0-mae:0.04957
# [210]	validation_0-mae:0.04957
# [211]	validation_0-mae:0.04925
# [212]	validation_0-mae:0.04892
# [213]	validation_0-mae:0.04861
# [214]	validation_0-mae:0.04829
# [215]	validation_0-mae:0.04797
# [216]	validation_0-mae:0.04766
# [217]	validation_0-mae:0.04766
# [218]	validation_0-mae:0.04766
# [219]	validation_0-mae:0.04735
# [220]	validation_0-mae:0.04704
# [221]	validation_0-mae:0.04673
# [222]	validation_0-mae:0.04673
# [223]	validation_0-mae:0.04643
# [224]	validation_0-mae:0.04643
# [225]	validation_0-mae:0.04613
# [226]	validation_0-mae:0.04583
# [227]	validation_0-mae:0.04553
# [228]	validation_0-mae:0.04523
# [229]	validation_0-mae:0.04493
# [230]	validation_0-mae:0.04464
# [231]	validation_0-mae:0.04435
# [232]	validation_0-mae:0.04406
# [233]	validation_0-mae:0.04377
# [234]	validation_0-mae:0.04349
# [235]	validation_0-mae:0.04349
# [236]	validation_0-mae:0.04321
# [237]	validation_0-mae:0.04292
# [238]	validation_0-mae:0.04264
# [239]	validation_0-mae:0.04237
# [240]	validation_0-mae:0.04209
# [241]	validation_0-mae:0.04209
# [242]	validation_0-mae:0.04181
# [243]	validation_0-mae:0.04154
# [244]	validation_0-mae:0.04127
# [245]	validation_0-mae:0.04100
# [246]	validation_0-mae:0.04100
# [247]	validation_0-mae:0.04074
# [248]	validation_0-mae:0.04047
# [249]	validation_0-mae:0.04047
# [250]	validation_0-mae:0.04047
# [251]	validation_0-mae:0.04021
# [252]	validation_0-mae:0.03994
# [253]	validation_0-mae:0.03968
# [254]	validation_0-mae:0.03942
# [255]	validation_0-mae:0.03917
# [256]	validation_0-mae:0.03891
# [257]	validation_0-mae:0.03866
# [258]	validation_0-mae:0.03841
# [259]	validation_0-mae:0.03816
# [260]	validation_0-mae:0.03791
# [261]	validation_0-mae:0.03766
# [262]	validation_0-mae:0.03742
# [263]	validation_0-mae:0.03717
# [264]	validation_0-mae:0.03693
# [265]	validation_0-mae:0.03693
# [266]	validation_0-mae:0.03693
# [267]	validation_0-mae:0.03669
# [268]	validation_0-mae:0.03669
# [269]	validation_0-mae:0.03645
# [270]	validation_0-mae:0.03621
# [271]	validation_0-mae:0.03598
# [272]	validation_0-mae:0.03574
# [273]	validation_0-mae:0.03574
# [274]	validation_0-mae:0.03551
# [275]	validation_0-mae:0.03551
# [276]	validation_0-mae:0.03528
# [277]	validation_0-mae:0.03528
# [278]	validation_0-mae:0.03505
# [279]	validation_0-mae:0.03482
# [280]	validation_0-mae:0.03459
# [281]	validation_0-mae:0.03437
# [282]	validation_0-mae:0.03414
# [283]	validation_0-mae:0.03392
# [284]	validation_0-mae:0.03392
# [285]	validation_0-mae:0.03370
# [286]	validation_0-mae:0.03348
# [287]	validation_0-mae:0.03326
# [288]	validation_0-mae:0.03305
# [289]	validation_0-mae:0.03283
# [290]	validation_0-mae:0.03262
# [291]	validation_0-mae:0.03262
# [292]	validation_0-mae:0.03240
# [293]	validation_0-mae:0.03219
# [294]	validation_0-mae:0.03198
# [295]	validation_0-mae:0.03178
# [296]	validation_0-mae:0.03157
# [297]	validation_0-mae:0.03136
# [298]	validation_0-mae:0.03116
# [299]	validation_0-mae:0.03096
#  10%|█         | 2/20 [04:53<44:26, 148.16s/it]
# [I 2022-11-28 11:03:52,879] Trial 1 finished with value: 0.030955931171774864 and parameters: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.951620032771144, 'reg_alpha': 3.8971436296150515, 'gamma': 4.379517251218031, 'colsample_bytree': 0.8306082160342882, 'subsample': 0.3569216411435332, 'learning_rate': 0.0065446432976429434, 'max_depth': 4, 'random_state': 2020, 'min_child_weight': 43, 'eval_metric': 'mae'}. Best is trial 0 with value: 0.0015295931370928884.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mae:0.14994
# [1]	validation_0-mae:0.14991
# [2]	validation_0-mae:0.14991
# [3]	validation_0-mae:0.14992
# [4]	validation_0-mae:0.13994
# [5]	validation_0-mae:0.13994
# [6]	validation_0-mae:0.13997
# [7]	validation_0-mae:0.14001
# [8]	validation_0-mae:0.14001
# [9]	validation_0-mae:0.13998
# [10]	validation_0-mae:0.13997
# [11]	validation_0-mae:0.13995
# [12]	validation_0-mae:0.13998
# [13]	validation_0-mae:0.13997
# [14]	validation_0-mae:0.13999
# [15]	validation_0-mae:0.13998
# [16]	validation_0-mae:0.13998
# [17]	validation_0-mae:0.13995
# [18]	validation_0-mae:0.13992
# [19]	validation_0-mae:0.13993
# [20]	validation_0-mae:0.13995
# [21]	validation_0-mae:0.13996
# [22]	validation_0-mae:0.13064
# [23]	validation_0-mae:0.13066
# [24]	validation_0-mae:0.13064
# [25]	validation_0-mae:0.13065
# [26]	validation_0-mae:0.13061
# [27]	validation_0-mae:0.13063
# [28]	validation_0-mae:0.13061
# [29]	validation_0-mae:0.13062
# [30]	validation_0-mae:0.13063
# [31]	validation_0-mae:0.13067
# [32]	validation_0-mae:0.13066
# [33]	validation_0-mae:0.13065
# [34]	validation_0-mae:0.12195
# [35]	validation_0-mae:0.12193
# [36]	validation_0-mae:0.12191
# [37]	validation_0-mae:0.12191
# [38]	validation_0-mae:0.12194
# [39]	validation_0-mae:0.11382
# [40]	validation_0-mae:0.11382
# [41]	validation_0-mae:0.11381
# [42]	validation_0-mae:0.10623
# [43]	validation_0-mae:0.10622
# [44]	validation_0-mae:0.10624
# [45]	validation_0-mae:0.10625
# [46]	validation_0-mae:0.10627
# [47]	validation_0-mae:0.10625
# [48]	validation_0-mae:0.10625
# [49]	validation_0-mae:0.10623
# [50]	validation_0-mae:0.10622
# [51]	validation_0-mae:0.10622
# [52]	validation_0-mae:0.10622
# [53]	validation_0-mae:0.10622
# [54]	validation_0-mae:0.10625
# [55]	validation_0-mae:0.10624
# [56]	validation_0-mae:0.10623
# [57]	validation_0-mae:0.10623
# [58]	validation_0-mae:0.10623
# [59]	validation_0-mae:0.10622
# [60]	validation_0-mae:0.10623
# [61]	validation_0-mae:0.10624
# [62]	validation_0-mae:0.10624
# [63]	validation_0-mae:0.10622
# [64]	validation_0-mae:0.10622
# [65]	validation_0-mae:0.10623
# [66]	validation_0-mae:0.10623
# [67]	validation_0-mae:0.10623
# [68]	validation_0-mae:0.10624
# [69]	validation_0-mae:0.09916
# [70]	validation_0-mae:0.09917
# [71]	validation_0-mae:0.09918
# [72]	validation_0-mae:0.09920
# [73]	validation_0-mae:0.09918
# [74]	validation_0-mae:0.09258
# [75]	validation_0-mae:0.09260
# [76]	validation_0-mae:0.09262
# [77]	validation_0-mae:0.08645
# [78]	validation_0-mae:0.08645
# [79]	validation_0-mae:0.08645
# [80]	validation_0-mae:0.08643
# [81]	validation_0-mae:0.08642
# [82]	validation_0-mae:0.08641
# [83]	validation_0-mae:0.08640
# [84]	validation_0-mae:0.08641
# [85]	validation_0-mae:0.08638
# [86]	validation_0-mae:0.08639
# [87]	validation_0-mae:0.08638
# [88]	validation_0-mae:0.08639
# [89]	validation_0-mae:0.08639
# [90]	validation_0-mae:0.08640
# [91]	validation_0-mae:0.08639
# [92]	validation_0-mae:0.08638
# [93]	validation_0-mae:0.08640
# [94]	validation_0-mae:0.08639
# [95]	validation_0-mae:0.08640
# [96]	validation_0-mae:0.08639
# [97]	validation_0-mae:0.08640
# [98]	validation_0-mae:0.08641
# [99]	validation_0-mae:0.08642
# [100]	validation_0-mae:0.08643
# [101]	validation_0-mae:0.08643
# [102]	validation_0-mae:0.08643
# [103]	validation_0-mae:0.08643
# [104]	validation_0-mae:0.08642
#  15%|█▌        | 3/20 [05:56<30:54, 109.07s/it]
# [I 2022-11-28 11:04:55,435] Trial 2 finished with value: 0.08638197183609009 and parameters: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.0858228523919987, 'reg_alpha': 1.4078405994341536, 'gamma': 4.318764216130164, 'colsample_bytree': 0.05916124820707591, 'subsample': 0.055289031023966984, 'learning_rate': 0.06661414404578787, 'max_depth': 3, 'random_state': 2020, 'min_child_weight': 145, 'eval_metric': 'mae'}. Best is trial 0 with value: 0.0015295931370928884.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mae:0.14108
# [1]	validation_0-mae:0.13278
# [2]	validation_0-mae:0.12497
# [3]	validation_0-mae:0.11762
# [4]	validation_0-mae:0.11070
# [5]	validation_0-mae:0.10418
# [6]	validation_0-mae:0.09805
# [7]	validation_0-mae:0.09228
# [8]	validation_0-mae:0.08685
# [9]	validation_0-mae:0.08174
# [10]	validation_0-mae:0.07693
# [11]	validation_0-mae:0.07241
# [12]	validation_0-mae:0.06815
# [13]	validation_0-mae:0.06414
# [14]	validation_0-mae:0.06036
# [15]	validation_0-mae:0.05681
# [102]	validation_0-mae:0.00142
# [103]	validation_0-mae:0.00142
# [104]	validation_0-mae:0.00142
# [105]	validation_0-mae:0.00142
# [106]	validation_0-mae:0.00142
# [107]	validation_0-mae:0.00142
# [108]	validation_0-mae:0.00142
# [109]	validation_0-mae:0.00142
# [110]	validation_0-mae:0.00142
# [111]	validation_0-mae:0.00142
# [112]	validation_0-mae:0.00142
# [113]	validation_0-mae:0.00142
# [114]	validation_0-mae:0.00142
# [115]	validation_0-mae:0.00142
# [116]	validation_0-mae:0.00142
# [117]	validation_0-mae:0.00142
# [118]	validation_0-mae:0.00142
# [119]	validation_0-mae:0.00142
# [120]	validation_0-mae:0.00142
# [121]	validation_0-mae:0.00142
# [122]	validation_0-mae:0.00142
# [123]	validation_0-mae:0.00142
# [124]	validation_0-mae:0.00142
# [125]	validation_0-mae:0.00142
# [126]	validation_0-mae:0.00142
# [127]	validation_0-mae:0.00142
#  20%|██        | 4/20 [07:11<25:33, 95.83s/it]
# [I 2022-11-28 11:06:10,960] Trial 3 finished with value: 0.0014188202330842614 and parameters: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.06282602957116043, 'reg_alpha': 2.0117153388977527, 'gamma': 4.174687244371697, 'colsample_bytree': 0.9918576118038304, 'subsample': 0.7772513874534244, 'learning_rate': 0.05884316210903026, 'max_depth': 5, 'random_state': 2020, 'min_child_weight': 148, 'eval_metric': 'mae'}. Best is trial 3 with value: 0.0014188202330842614.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mae:0.14442
# [1]	validation_0-mae:0.13914
# [2]	validation_0-mae:0.13405
# [3]	validation_0-mae:0.12915
# [4]	validation_0-mae:0.12443
# [5]	validation_0-mae:0.11988
# [6]	validation_0-mae:0.11550
# [7]	validation_0-mae:0.11127
# [8]	validation_0-mae:0.11127
# [9]	validation_0-mae:0.10721
# [10]	validation_0-mae:0.10329
# [11]	validation_0-mae:0.09951
# [12]	validation_0-mae:0.09587
# [13]	validation_0-mae:0.09236
# [14]	validation_0-mae:0.08899
# [15]	validation_0-mae:0.08573
# [16]	validation_0-mae:0.08260
# [17]	validation_0-mae:0.07958
# [18]	validation_0-mae:0.07667
# [19]	validation_0-mae:0.07672
# [20]	validation_0-mae:0.07391
# [21]	validation_0-mae:0.07121
# [22]	validation_0-mae:0.06861
# [23]	validation_0-mae:0.06610
# [24]	validation_0-mae:0.06369
# [25]	validation_0-mae:0.06369
# [26]	validation_0-mae:0.06136
# [27]	validation_0-mae:0.06136
# [28]	validation_0-mae:0.05912
# [29]	validation_0-mae:0.05696
# [30]	validation_0-mae:0.05696
# [31]	validation_0-mae:0.05696
# [32]	validation_0-mae:0.05488
# [33]	validation_0-mae:0.05488
# [34]	validation_0-mae:0.05288
# [35]	validation_0-mae:0.05095
# [36]	validation_0-mae:0.04908
# [37]	validation_0-mae:0.04729
# [38]	validation_0-mae:0.04556
# [39]	validation_0-mae:0.04390
# [40]	validation_0-mae:0.04230
# [41]	validation_0-mae:0.04230
# [42]	validation_0-mae:0.04075
# [43]	validation_0-mae:0.03927
# [215]	validation_0-mae:0.00232
# [216]	validation_0-mae:0.00232
# [217]	validation_0-mae:0.00232
# [218]	validation_0-mae:0.00232
# [219]	validation_0-mae:0.00232
# [220]	validation_0-mae:0.00232
# [221]	validation_0-mae:0.00232
# [222]	validation_0-mae:0.00232
# [223]	validation_0-mae:0.00232
#  25%|██▌       | 5/20 [08:57<24:49, 99.33s/it]
# [I 2022-11-28 11:07:56,504] Trial 4 finished with value: 0.0023187745828181505 and parameters: {'n_estimators': 700, 'objective': 'reg:squarederror', 'reg_lambda': 0.9498537233096949, 'reg_alpha': 3.1269875686460065, 'gamma': 4.506984577461225, 'colsample_bytree': 0.7375967917177928, 'subsample': 0.31979906496027555, 'learning_rate': 0.03657237746703636, 'max_depth': 5, 'random_state': 2020, 'min_child_weight': 180, 'eval_metric': 'mae'}. Best is trial 3 with value: 0.0014188202330842614.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mae:0.14081
# [1]	validation_0-mae:0.13227
# [2]	validation_0-mae:0.12425
# [3]	validation_0-mae:0.11671
# [4]	validation_0-mae:0.10963
# [5]	validation_0-mae:0.10298
# [6]	validation_0-mae:0.09674
# [7]	validation_0-mae:0.09087
# [8]	validation_0-mae:0.09095
# [9]	validation_0-mae:0.08544
# [10]	validation_0-mae:0.08026
# [11]	validation_0-mae:0.07540
# [12]	validation_0-mae:0.07083
# [13]	validation_0-mae:0.07087
# [14]	validation_0-mae:0.06658
# [15]	validation_0-mae:0.06255
# [16]	validation_0-mae:0.05876
# [17]	validation_0-mae:0.05879
# [18]	validation_0-mae:0.05883
# [19]	validation_0-mae:0.05886
# [20]	validation_0-mae:0.05531
# [21]	validation_0-mae:0.05197
# [22]	validation_0-mae:0.04883
# [23]	validation_0-mae:0.04588
# [24]	validation_0-mae:0.04312
# [25]	validation_0-mae:0.04314
# [26]	validation_0-mae:0.04054
# [27]	validation_0-mae:0.04055
# [28]	validation_0-mae:0.03811
# [29]	validation_0-mae:0.03812
# [30]	validation_0-mae:0.03812
# [31]	validation_0-mae:0.03812
# [32]	validation_0-mae:0.03583
# [33]	validation_0-mae:0.03583
# [34]	validation_0-mae:0.03367
# [35]	validation_0-mae:0.03165
# [36]	validation_0-mae:0.02975
# [37]	validation_0-mae:0.02796
# [38]	validation_0-mae:0.02628
# [39]	validation_0-mae:0.02471
# [40]	validation_0-mae:0.02323
# [41]	validation_0-mae:0.02323
# [42]	validation_0-mae:0.02184
# [43]	validation_0-mae:0.02184
# [44]	validation_0-mae:0.02053
# [45]	validation_0-mae:0.01930
# [46]	validation_0-mae:0.01815
# [47]	validation_0-mae:0.01707
# [48]	validation_0-mae:0.01605
# [49]	validation_0-mae:0.01509
# [50]	validation_0-mae:0.01420
# [51]	validation_0-mae:0.01335
# [52]	validation_0-mae:0.01256
# [53]	validation_0-mae:0.01256
# [54]	validation_0-mae:0.01256
# [55]	validation_0-mae:0.01182
# [56]	validation_0-mae:0.01112
# [57]	validation_0-mae:0.01046
# [58]	validation_0-mae:0.01046
# [59]	validation_0-mae:0.00985
# [60]	validation_0-mae:0.00927
# [61]	validation_0-mae:0.00872
# [147]	validation_0-mae:0.00099
# [148]	validation_0-mae:0.00099
# [149]	validation_0-mae:0.00099
# [150]	validation_0-mae:0.00099
# [151]	validation_0-mae:0.00099
# [152]	validation_0-mae:0.00099
# [153]	validation_0-mae:0.00099
# [154]	validation_0-mae:0.00099
# [155]	validation_0-mae:0.00099
# [156]	validation_0-mae:0.00099
# [157]	validation_0-mae:0.00099
# [158]	validation_0-mae:0.00099
# [159]	validation_0-mae:0.00099
# [160]	validation_0-mae:0.00099
#  30%|███       | 6/20 [10:21<22:00, 94.30s/it]
# [I 2022-11-28 11:09:21,037] Trial 5 finished with value: 0.0009924035985022783 and parameters: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.9600341204525804, 'reg_alpha': 0.07855811026900472, 'gamma': 1.0036481295357302, 'colsample_bytree': 0.6881113467654387, 'subsample': 0.8818520861043739, 'learning_rate': 0.0606575491282112, 'max_depth': 4, 'random_state': 2020, 'min_child_weight': 179, 'eval_metric': 'mae'}. Best is trial 5 with value: 0.0009924035985022783.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
#  35%|███▌      | 7/20 [10:45<15:26, 71.26s/it]
# [I 2022-11-28 11:09:44,859] Trial 6 pruned. Trial was pruned at iteration 0.
#  40%|████      | 8/20 [11:26<12:20, 61.67s/it]
# [I 2022-11-28 11:10:25,939] Trial 7 pruned. Trial was pruned at iteration 0.
# [0]	validation_0-mae:0.14996
#  45%|████▌     | 9/20 [12:07<10:05, 55.01s/it]
# [I 2022-11-28 11:11:06,346] Trial 8 pruned. Trial was pruned at iteration 0.
# [0]	validation_0-mae:0.15005
#  50%|█████     | 10/20 [12:48<08:29, 50.90s/it]
# [I 2022-11-28 11:11:48,046] Trial 9 pruned. Trial was pruned at iteration 0.
#  55%|█████▌    | 11/20 [13:43<07:47, 51.91s/it]
# [I 2022-11-28 11:12:39,749] Trial 10 pruned. Trial was pruned at iteration 0.
# [0]	validation_0-mae:0.14432
# [1]	validation_0-mae:0.13894
# [2]	validation_0-mae:0.13376
# [3]	validation_0-mae:0.12877
# [4]	validation_0-mae:0.12397
# [5]	validation_0-mae:0.11935
# [6]	validation_0-mae:0.11490
# [7]	validation_0-mae:0.11062
# [8]	validation_0-mae:0.10649
# [9]	validation_0-mae:0.10252
# [10]	validation_0-mae:0.09870
# [11]	validation_0-mae:0.09502
# [12]	validation_0-mae:0.09148
# [13]	validation_0-mae:0.08807
# [14]	validation_0-mae:0.08478
# [15]	validation_0-mae:0.08162
# [16]	validation_0-mae:0.07858
# [17]	validation_0-mae:0.07565
# [18]	validation_0-mae:0.07283
# [19]	validation_0-mae:0.07012
# [20]	validation_0-mae:0.06750
# [21]	validation_0-mae:0.06499
# [22]	validation_0-mae:0.06256
# [23]	validation_0-mae:0.06023
# [24]	validation_0-mae:0.05799
# [25]	validation_0-mae:0.05582
# [26]	validation_0-mae:0.05374
# [27]	validation_0-mae:0.05174
# [28]	validation_0-mae:0.04981
# [29]	validation_0-mae:0.04795
# [30]	validation_0-mae:0.04617
# [31]	validation_0-mae:0.04444
# [32]	validation_0-mae:0.04279
# [33]	validation_0-mae:0.04119
# [34]	validation_0-mae:0.03966
# [35]	validation_0-mae:0.03818
# [36]	validation_0-mae:0.03676
# [37]	validation_0-mae:0.03539
# [38]	validation_0-mae:0.03407
# [39]	validation_0-mae:0.03280
# [40]	validation_0-mae:0.03157
# [41]	validation_0-mae:0.03040
# [42]	validation_0-mae:0.02926
# [43]	validation_0-mae:0.02817
# [44]	validation_0-mae:0.02712
# [45]	validation_0-mae:0.02611
# [46]	validation_0-mae:0.02514
# [47]	validation_0-mae:0.02420
# [48]	validation_0-mae:0.02330
# [49]	validation_0-mae:0.02243
# [50]	validation_0-mae:0.02159
# [51]	validation_0-mae:0.02079
# [52]	validation_0-mae:0.02002
# [53]	validation_0-mae:0.01927
# [54]	validation_0-mae:0.01855
# [55]	validation_0-mae:0.01786
# [56]	validation_0-mae:0.01719
# [57]	validation_0-mae:0.01655
# [58]	validation_0-mae:0.01594
# [59]	validation_0-mae:0.01534
# [60]	validation_0-mae:0.01477
# [61]	validation_0-mae:0.01422
# [62]	validation_0-mae:0.01369
# [63]	validation_0-mae:0.01318
# [64]	validation_0-mae:0.01269
# [65]	validation_0-mae:0.01222
# [66]	validation_0-mae:0.01176
# [67]	validation_0-mae:0.01132
# [68]	validation_0-mae:0.01090
# [69]	validation_0-mae:0.01049
# [70]	validation_0-mae:0.01010
# [71]	validation_0-mae:0.00973
# [72]	validation_0-mae:0.00936
# [73]	validation_0-mae:0.00901
# [74]	validation_0-mae:0.00868
# [75]	validation_0-mae:0.00836
# [76]	validation_0-mae:0.00804
# [77]	validation_0-mae:0.00774
# [78]	validation_0-mae:0.00746
# [79]	validation_0-mae:0.00718
# [80]	validation_0-mae:0.00691
# [81]	validation_0-mae:0.00665
# [82]	validation_0-mae:0.00641
# [83]	validation_0-mae:0.00617
# [84]	validation_0-mae:0.00594
# [85]	validation_0-mae:0.00572
# [86]	validation_0-mae:0.00550
# [87]	validation_0-mae:0.00530
# [88]	validation_0-mae:0.00510
# [89]	validation_0-mae:0.00491
# [90]	validation_0-mae:0.00473
# [91]	validation_0-mae:0.00455
# [92]	validation_0-mae:0.00438
# [93]	validation_0-mae:0.00422
# [94]	validation_0-mae:0.00406
# [95]	validation_0-mae:0.00391
# [96]	validation_0-mae:0.00376
# [97]	validation_0-mae:0.00362
# [98]	validation_0-mae:0.00349
# [99]	validation_0-mae:0.00336
# [100]	validation_0-mae:0.00323
# ...
# [152]	validation_0-mae:0.00110
# [153]	validation_0-mae:0.00110
# [154]	validation_0-mae:0.00110
# [155]	validation_0-mae:0.00110
# [156]	validation_0-mae:0.00110
#  60%|██████    | 12/20 [15:43<09:42, 72.76s/it]
# [I 2022-11-28 11:14:42,702] Trial 11 finished with value: 0.0011043463600799441 and parameters: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.32943148728596217, 'reg_alpha': 1.8960928791305047, 'gamma': 3.0289095708698324, 'colsample_bytree': 0.9987166983430296, 'subsample': 0.9336333358113397, 'learning_rate': 0.03728162646031609, 'max_depth': 5, 'random_state': 2020, 'min_child_weight': 114, 'eval_metric': 'mae'}. Best is trial 5 with value: 0.0009924035985022783.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
#  75%|███████▌  | 15/20 [18:43<05:13, 62.61s/it]
# [I 2022-11-28 11:17:42,266] Trial 14 pruned. Trial was pruned at iteration 0.
# [0]	validation_0-mae:0.15013
#  80%|████████  | 16/20 [19:25<03:45, 56.42s/it]
# [I 2022-11-28 11:18:24,301] Trial 15 pruned. Trial was pruned at iteration 0.
# [0]	validation_0-mae:0.14225
# [1]	validation_0-mae:0.13498
# [2]	validation_0-mae:0.12809
# [3]	validation_0-mae:0.12154
# [4]	validation_0-mae:0.11534
# [5]	validation_0-mae:0.10944
# [6]	validation_0-mae:0.10385
# [7]	validation_0-mae:0.09855
# [8]	validation_0-mae:0.09863
# [9]	validation_0-mae:0.09360
# [10]	validation_0-mae:0.08882
# [11]	validation_0-mae:0.08429
# [12]	validation_0-mae:0.07999
# [13]	validation_0-mae:0.08002
# [14]	validation_0-mae:0.07594
# [15]	validation_0-mae:0.07207
# [16]	validation_0-mae:0.06839
# [17]	validation_0-mae:0.06843
# [18]	validation_0-mae:0.06846
# [19]	validation_0-mae:0.06850
# [20]	validation_0-mae:0.06502
# [21]	validation_0-mae:0.06171
# [22]	validation_0-mae:0.05857
# [23]	validation_0-mae:0.05559
# [24]	validation_0-mae:0.05276
# [25]	validation_0-mae:0.05279
# [26]	validation_0-mae:0.05011
# [27]	validation_0-mae:0.05013
# [28]	validation_0-mae:0.05015
# [29]	validation_0-mae:0.05016
# [30]	validation_0-mae:0.05016
# [31]	validation_0-mae:0.05018
# [32]	validation_0-mae:0.04764
# [33]	validation_0-mae:0.04764
# [34]	validation_0-mae:0.04522
# [35]	validation_0-mae:0.04293
# [36]	validation_0-mae:0.04076
# [37]	validation_0-mae:0.03869
# [38]	validation_0-mae:0.03674
# [39]	validation_0-mae:0.03488
# [40]	validation_0-mae:0.03311
# [41]	validation_0-mae:0.03311
# [42]	validation_0-mae:0.03144
# [43]	validation_0-mae:0.03144
# [44]	validation_0-mae:0.02985
# [45]	validation_0-mae:0.02835
# [46]	validation_0-mae:0.02692
# [47]	validation_0-mae:0.02556
# [48]	validation_0-mae:0.02427
# [49]	validation_0-mae:0.02305
# [50]	validation_0-mae:0.02189
# [51]	validation_0-mae:0.02079
# [52]	validation_0-mae:0.01975
# [53]	validation_0-mae:0.01975
# [54]	validation_0-mae:0.01975
# [55]	validation_0-mae:0.01876
# [56]	validation_0-mae:0.01782
# [57]	validation_0-mae:0.01693
# [58]	validation_0-mae:0.01693
# [59]	validation_0-mae:0.01608
# [60]	validation_0-mae:0.01528
# [61]	validation_0-mae:0.01451
# [62]	validation_0-mae:0.01451
# [63]	validation_0-mae:0.01379
# [64]	validation_0-mae:0.01379
# [35]	validation_0-mae:0.00895
# [36]	validation_0-mae:0.00824
# [37]	validation_0-mae:0.00759
# [38]	validation_0-mae:0.00699
# [39]	validation_0-mae:0.00644
# [40]	validation_0-mae:0.00593
# [41]	validation_0-mae:0.00593
# [42]	validation_0-mae:0.00546
# [43]	validation_0-mae:0.00502
# [44]	validation_0-mae:0.00463
# [45]	validation_0-mae:0.00426
# [46]	validation_0-mae:0.00393
# [47]	validation_0-mae:0.00374
# [48]	validation_0-mae:0.00344
# [49]	validation_0-mae:0.00328
# [50]	validation_0-mae:0.00302
# [51]	validation_0-mae:0.00287
# [52]	validation_0-mae:0.00264
# [53]	validation_0-mae:0.00257
# [54]	validation_0-mae:0.00237
# [55]	validation_0-mae:0.00231
# [56]	validation_0-mae:0.00213
# [57]	validation_0-mae:0.00210
# [58]	validation_0-mae:0.00204
# [59]	validation_0-mae:0.00204
# [60]	validation_0-mae:0.00204
# [61]	validation_0-mae:0.00204
# [62]	validation_0-mae:0.00204
# [63]	validation_0-mae:0.00204
# [64]	validation_0-mae:0.00204
# [65]	validation_0-mae:0.00204
# [66]	validation_0-mae:0.00204
# [67]	validation_0-mae:0.00204
# [68]	validation_0-mae:0.00204
# [69]	validation_0-mae:0.00204
# [70]	validation_0-mae:0.00204
# [71]	validation_0-mae:0.00204
# [72]	validation_0-mae:0.00204
# [73]	validation_0-mae:0.00204
# [74]	validation_0-mae:0.00204
# [75]	validation_0-mae:0.00204
# [76]	validation_0-mae:0.00204
# [77]	validation_0-mae:0.00204
#  95%|█████████▌| 19/20 [22:36<00:59, 59.48s/it]
# [I 2022-11-28 11:21:36,132] Trial 18 finished with value: 0.002035460202023387 and parameters: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.21907157668734323, 'reg_alpha': 4.934030243902859, 'gamma': 1.8343608180378967, 'colsample_bytree': 0.9099046146283366, 'subsample': 0.1663568763646931, 'learning_rate': 0.07972915383407803, 'max_depth': 4, 'random_state': 2020, 'min_child_weight': 82, 'eval_metric': 'mae'}. Best is trial 5 with value: 0.0009924035985022783.
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `callbacks` in `fit` method is deprecated for better compatibility with scikit-learn, use `callbacks` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mae:0.14267
# [1]	validation_0-mae:0.13578
# [2]	validation_0-mae:0.12923
# [3]	validation_0-mae:0.12299
# [4]	validation_0-mae:0.11706
# [5]	validation_0-mae:0.11141
# [6]	validation_0-mae:0.10603
# [7]	validation_0-mae:0.10092
# [8]	validation_0-mae:0.10092
# [9]	validation_0-mae:0.09605
# [10]	validation_0-mae:0.09141
# [11]	validation_0-mae:0.08700
# [12]	validation_0-mae:0.08280
# [13]	validation_0-mae:0.07881
# [14]	validation_0-mae:0.07500
# [15]	validation_0-mae:0.07138
# [16]	validation_0-mae:0.06794
# [17]	validation_0-mae:0.06466
# [18]	validation_0-mae:0.06471
# [19]	validation_0-mae:0.06476
# [20]	validation_0-mae:0.06164
# [21]	validation_0-mae:0.05867
# [22]	validation_0-mae:0.05585
# [23]	validation_0-mae:0.05316
# [24]	validation_0-mae:0.05060
# [25]	validation_0-mae:0.05060
# [26]	validation_0-mae:0.04816
# [27]	validation_0-mae:0.04816
# [28]	validation_0-mae:0.04584
# [29]	validation_0-mae:0.04363
# [30]	validation_0-mae:0.04363
# [31]	validation_0-mae:0.04363
# [32]	validation_0-mae:0.04153
# [33]	validation_0-mae:0.04153
# 100%|██████████| 20/20 [23:27<00:00, 70.39s/it]
# [I 2022-11-28 11:22:26,919] Trial 19 pruned. Trial was pruned at iteration 33.
# Number of finished trials: 20
# Best trial: {'n_estimators': 300, 'objective': 'reg:squarederror', 'reg_lambda': 0.9600341204525804, 'reg_alpha': 0.07855811026900472, 'gamma': 1.0036481295357302, 'colsample_bytree': 0.6881113467654387, 'subsample': 0.8818520861043739, 'learning_rate': 0.0606575491282112, 'max_depth': 4, 'random_state': 2020, 'min_child_weight': 179, 'eval_metric': 'mae'}
# 6325

# %%
y
# Out:
# id
# n000101811a8a843    0.50
# n001e1318d5072ac    0.00
# n002a9c5ab785cbb    0.50
# n002ccf6d0e8c5ad    0.25
# n0051ab821295c29    0.50
#                     ...
# nffcc311c1b4ffb2     NaN
# nffcca880507acfc     NaN
# nffce3e57217e7a3     NaN
# nffd5ec0564586e7     NaN
# nffe284f043b586f     NaN
# Name: target_nomi_v4_20, Length: 2366074, dtype: float32

# %%
gc.collect()

validation_data = categorical_encoded(validation_data)
    
X = validation_data.drop(target, axis=1)
y = validation_data[target]


if os.path.exists(f'best_trial_{current_round}.parquet'):
    trial = study.trials_dataframe()
    trial_best_score = trial['value'].min()

    historic_best_studies = pd.read_parquet(f'best_trial_{current_round}.parquet')
    historic_best_score = historic_best_studies['value'].min()

    if trial_best_score > historic_best_score:
        print_both(file, f'- Current best score: {trial_best_score} is no improvement over historic best score: {historic_best_score}, do nothing')
        
    else:
        print_both(file, f'- Current best score: {trial_best_score} is an improvement over historic best score: {historic_best_score}, update best trial')
        trial.to_parquet(f'best_trial_{current_round}.parquet')
        print_both(file, f'- Data saved to best_trial_{current_round}.parquet')
        
        best_trial = study.best_trial.params
        best_trial['tree_method'] = 'hist'

        model = xgb.XGBRegressor(**best_trial)
        model.fit(X, y)

        preds = model.predict(X)

        print_both(file, f"MAE for set: {mean_absolute_error(y, preds)}")
        print_both(file, f"R2 for set: {r2_score(y, preds)}")
        joblib.dump(model, f'{current_round}_predictor.joblib')
else:
    trial = study.trials_dataframe()
    trial.to_parquet(f'best_trial_{current_round}.parquet')
    best_trial = study.best_trial.params
    best_trial['tree_method'] = 'hist'

    model = xgb.XGBRegressor(**best_trial)
    model.fit(X, y)

    preds = model.predict(X)

    print_both(file, f"MAE for set: {mean_absolute_error(y, preds)}")
    print_both(file, f"R2 for set: {r2_score(y, preds)}")
    joblib.dump(model, f'{current_round}_predictor.joblib')
# Out:
# Names of categorical columns :  ['era', 'data_type']
# - Current best score: 0.0009924035985022783 is an improvement over historic best score: 0.0009924035985022783, update best trial
# - Data saved to best_trial_364.parquet
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# c:\Users\PC\Documents\Github\numerai_research\research.ipynb Cell 9 in <cell line: 9>()
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X15sZmlsZQ%3D%3D?line=24'>25</a> best_trial['tree_method'] = 'hist'
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X15sZmlsZQ%3D%3D?line=26'>27</a> model = xgb.XGBRegressor(**best_trial)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a> model.fit(X, y)
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X15sZmlsZQ%3D%3D?line=29'>30</a> preds = model.predict(X)
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X15sZmlsZQ%3D%3D?line=31'>32</a> print_both(file, f"MAE for set: {mean_absolute_error(y, preds)}")
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:931, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     880 """Fit gradient boosting model.
#     881
#     882 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     928         Use `callbacks` in :py:meth:`__init__` or :py:meth:`set_params` instead.
#     929 """
#     930 evals_result: TrainingCallback.EvalsLog = {}
# --> 931 train_dmatrix, evals = _wrap_evaluation_matrices(
#     932     missing=self.missing,
#     933     X=X,
#     934     y=y,
#     935     group=None,
#     936     qid=None,
#     937     sample_weight=sample_weight,
#     938     base_margin=base_margin,
#     939     feature_weights=feature_weights,
#     940     eval_set=eval_set,
#     941     sample_weight_eval_set=sample_weight_eval_set,
#     942     base_margin_eval_set=base_margin_eval_set,
#     943     eval_group=None,
#     944     eval_qid=None,
#     945     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     946     enable_categorical=self.enable_categorical,
#     947 )
#     948 params = self.get_xgb_params()
#     950 if callable(self.objective):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:401, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical)
#     381 def _wrap_evaluation_matrices(
#     382     missing: float,
#     383     X: Any,
#    (...)
#     396     enable_categorical: bool,
#     397 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     398     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the way.
#     399
#     400     """
# --> 401     train_dmatrix = create_dmatrix(
#     402         data=X,
#     403         label=y,
#     404         group=group,
#     405         qid=qid,
#     406         weight=sample_weight,
#     407         base_margin=base_margin,
#     408         feature_weights=feature_weights,
#     409         missing=missing,
#     410         enable_categorical=enable_categorical,
#     411     )
#     413     n_validation = 0 if eval_set is None else len(eval_set)
#     415     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:945, in XGBModel.fit.<locals>.<lambda>(**kwargs)
#     880 """Fit gradient boosting model.
#     881
#     882 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     928         Use `callbacks` in :py:meth:`__init__` or :py:meth:`set_params` instead.
#     929 """
#     930 evals_result: TrainingCallback.EvalsLog = {}
#     931 train_dmatrix, evals = _wrap_evaluation_matrices(
#     932     missing=self.missing,
#     933     X=X,
#     934     y=y,
#     935     group=None,
#     936     qid=None,
#     937     sample_weight=sample_weight,
#     938     base_margin=base_margin,
#     939     feature_weights=feature_weights,
#     940     eval_set=eval_set,
#     941     sample_weight_eval_set=sample_weight_eval_set,
#     942     base_margin_eval_set=base_margin_eval_set,
#     943     eval_group=None,
#     944     eval_qid=None,
# --> 945     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     946     enable_categorical=self.enable_categorical,
#     947 )
#     948 params = self.get_xgb_params()
#     950 if callable(self.objective):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:654, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     651 assert handle is not None
#     652 self.handle = handle
# --> 654 self.set_info(
#     655     label=label,
#     656     weight=weight,
#     657     base_margin=base_margin,
#     658     group=group,
#     659     qid=qid,
#     660     label_lower_bound=label_lower_bound,
#     661     label_upper_bound=label_upper_bound,
#     662     feature_weights=feature_weights,
#     663 )
#     665 if feature_names is not None:
#     666     self.feature_names = feature_names
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:719, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     716 from .data import dispatch_meta_backend
#     718 if label is not None:
# --> 719     self.set_label(label)
#     720 if weight is not None:
#     721     self.set_weight(weight)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:850, in DMatrix.set_label(self, label)
#     842 """Set label of dmatrix
#     843
#     844 Parameters
#    (...)
#     847     The label information to be set into DMatrix
#     848 """
#     849 from .data import dispatch_meta_backend
# --> 850 dispatch_meta_backend(self, label, 'label', 'float')
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:1043, in dispatch_meta_backend(matrix, data, name, dtype)
#    1041     return
#    1042 if _is_pandas_series(data):
# -> 1043     _meta_from_pandas_series(data, name, dtype, handle)
#    1044     return
#    1045 if _is_dlpack(data):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:368, in _meta_from_pandas_series(data, name, dtype, handle)
#     366     data = data.to_dense()
#     367 assert len(data.shape) == 1 or data.shape[1] == 0 or data.shape[1] == 1
# --> 368 _meta_from_numpy(data, name, dtype, handle)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:976, in _meta_from_numpy(data, field, dtype, handle)
#     974     raise ValueError("Masked array is not supported.")
#     975 interface_str = _array_interface(data)
# --> 976 _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:203, in _check_call(ret)
#     192 """Check the return value of C API call
#     193
#     194 This function will raise exception when error occurs.
#    (...)
#     200     return value from API calls
#     201 """
#     202 if ret != 0:
# --> 203     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [11:24:50] C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/data/data.cc:487: Check failed: valid: Label contains NaN, infinity or a value too large.

# %%
 
read_columns = features + [ERA_COL, DATA_TYPE_COL, TARGET_COL]

# note: sometimes when trying to read the downloaded data you get an error about invalid magic parquet bytes...
# if so, delete the file and rerun the napi.download_dataset to fix the corrupted file
training_data = pd.read_parquet('v4/train.parquet',
                                columns=read_columns)
validation_data = pd.read_parquet('v4/validation.parquet',
                                  columns=read_columns)
live_data = pd.read_parquet(f'v4/live_{current_round}.parquet',
                                  columns=read_columns)
