# %%
import gc
import json
import optuna
import pandas as pd
import numpy as np
import xgboost as xgb

from pathlib import Path
from numerapi import NumerAPI
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score

from helper import print_both, categorical_encoded

napi = NumerAPI()
current_round = napi.get_current_round()

# %%
# Tournament data changes every week so we specify the round in their name. Training
# and validation data only change periodically, so no need to download them every time.
print('Downloading dataset files...')

Path("./v4").mkdir(parents=False, exist_ok=True)
napi.download_dataset("v4/train.parquet")
napi.download_dataset("v4/validation.parquet")
napi.download_dataset("v4/live.parquet", f"v4/live_{current_round}.parquet")
napi.download_dataset("v4/validation_example_preds.parquet")
napi.download_dataset("v4/features.json")

# %%
ERA_COL = "era"
TARGET_COL = "target_nomi_v4_20"
DATA_TYPE_COL = "data_type"
EXAMPLE_PREDS_COL = "example_preds"

print('Reading minimal training data')
with open("v4/features.json", "r") as f:
    feature_metadata = json.load(f)

features = feature_metadata["feature_sets"]["medium"]
read_columns = features + [ERA_COL, DATA_TYPE_COL, TARGET_COL]
# Out:
# Reading minimal training data

# %%
training_data = pd.read_parquet('v4/train.parquet', columns=read_columns)
training_data = training_data.replace([np.inf, -np.inf], np.nan)


validation_data = pd.read_parquet('v4/validation.parquet', columns=read_columns)
validation_data = validation_data.replace([np.inf, -np.inf], np.nan)

# %%
all_feature_corrs = training_data.groupby(ERA_COL).apply(lambda era: era[features].corrwith(era[TARGET_COL]))

# %%
def get_biggest_change_features(corrs, n):
    all_eras = corrs.index.sort_values()
    h1_eras = all_eras[:len(all_eras) // 2]
    h2_eras = all_eras[len(all_eras) // 2:]

    h1_corr_means = corrs.loc[h1_eras, :].mean()
    h2_corr_means = corrs.loc[h2_eras, :].mean()

    corr_diffs = h2_corr_means - h1_corr_means
    worst_n = corr_diffs.abs().sort_values(ascending=False).head(n).index.tolist()
    return worst_n

# %%
riskiest_features = get_biggest_change_features(all_feature_corrs, 50)

# %%
data = training_data.copy()
optuna_target = data[targets]

# %%
train_x, test_x, train_y, test_y = train_test_split(data, optuna_target, test_size=0.2, random_state=42)

# %%
data
# Out:
#                        id    era  data_type  \
# 0        n003bba8a98662e4    0.0        0.0
# 1        n003bee128c2fcfc    0.0        0.0
# 2        n0048ac83aff7194    0.0        0.0
# 3        n00691bec80d3e02    0.0        0.0
# 4        n00b8720a2fdc4f2    0.0        0.0
# ...                   ...    ...        ...
# 2420516  nffcc1dbdf2212e6  573.0        0.0
# 2420517  nffd71b7f6a128df  573.0        0.0
# 2420518  nffde3b371d67394  573.0        0.0
# 2420519  nfff1a1111b35e84  573.0        0.0
# 2420520  nfff2bd38e397265  573.0        0.0
#
#          feature_honoured_observational_balaamite  \
# 0                                            1.00
# 1                                            0.50
# 2                                            0.50
# 3                                            1.00
# 4                                            1.00
# ...                                           ...
# 2420516                                      0.00
# 2420517                                      0.00
# 2420518                                      0.25
# 2420519                                      1.00
# 2420520                                      0.25
#
#          feature_polaroid_vadose_quinze  feature_untidy_withdrawn_bargeman  \
# 0                                  0.50                               1.00
# 1                                  1.00                               0.25
# 2                                  0.25                               0.75
# 3                                  0.50                               0.50
# 4                                  0.75                               1.00
# ...                                 ...                                ...
# 2420516                            0.25                               0.00
# 2420517                            0.25                               0.00
# 2420518                            0.25                               0.50
# 2420519                            0.75                               0.50
# 2420520                            0.25                               0.75
#
#          feature_genuine_kyphotic_trehala  \
# 0                                    1.00
# 1                                    0.75
# 2                                    0.00
# 3                                    0.75
# 4                                    1.00
# ...                                   ...
# 2420516                              0.25
# 2420517                              1.00
# 2420518                              0.25
# 2420519                              0.50
# 2420520                              0.00
#
#          feature_unenthralled_sportful_schoolhouse  \
# 0                                             0.00
# 1                                             0.00
# 2                                             0.75
# 3                                             0.00
# 4                                             0.00
# ...                                            ...
# 2420516                                       1.00
# 2420517                                       0.50
# 2420518                                       0.75
# 2420519                                       0.75
# 2420520                                       0.50
#
#          feature_divulsive_explanatory_ideologue  \
# 0                                           0.00
# 1                                           0.75
# 2                                           0.00
# 3                                           1.00
# 4                                           0.00
# ...                                          ...
# 2420516                                     1.00
# 2420517                                     1.00
# 2420518                                     0.75
# 2420519                                     0.50
# 2420520                                     0.50
#
#          feature_ichthyotic_roofed_yeshiva  ...  target_paul_v4_20  \
# 0                                     1.00  ...               0.50
# 1                                     0.50  ...               0.75
# 2                                     0.75  ...               0.50
# 3                                     0.25  ...               0.50
# 4                                     1.00  ...               0.50
# ...                                    ...  ...                ...
# 2420516                               0.75  ...               0.50
# 2420517                               0.00  ...               0.25
# 2420518                               0.75  ...               0.25
# 2420519                               0.25  ...               0.75
# 2420520                               1.00  ...               0.50
#
#          target_paul_v4_60  target_george_v4_20  target_george_v4_60  \
# 0                     0.25                 0.25                 0.00
# 1                     1.00                 1.00                 1.00
# 2                     0.25                 0.25                 0.25
# 3                     0.50                 0.50                 0.50
# 4                     0.50                 0.50                 0.50
# ...                    ...                  ...                  ...
# 2420516               0.75                 0.75                 0.75
# 2420517               0.50                 0.25                 0.50
# 2420518               0.50                 0.50                 0.50
# 2420519               0.75                 0.75                 0.75
# 2420520               0.75                 0.50                 0.75
#
#          target_william_v4_20  target_william_v4_60  target_arthur_v4_20  \
# 0                    0.333333              0.000000             0.500000
# 1                    0.666667              0.666667             0.833333
# 2                    0.500000              0.333333             0.333333
# 3                    0.666667              0.500000             0.500000
# 4                    0.666667              0.500000             0.666667
# ...                       ...                   ...                  ...
# 2420516              0.666667              0.833333             0.500000
# 2420517              0.166667              0.500000             0.000000
# 2420518              0.333333              0.666667             0.500000
# 2420519              0.500000              0.666667             0.500000
# 2420520              0.833333              0.833333             0.666667
#
#          target_arthur_v4_60  target_thomas_v4_20  target_thomas_v4_60
# 0                   0.500000             0.166667             0.000000
# 1                   0.666667             0.833333             0.666667
# 2                   0.500000             0.500000             0.333333
# 3                   0.500000             0.666667             0.500000
# 4                   0.500000             0.666667             0.500000
# ...                      ...                  ...                  ...
# 2420516             0.833333             0.833333             0.833333
# 2420517             0.333333             0.166667             0.333333
# 2420518             0.666667             0.333333             0.666667
# 2420519             0.500000             0.500000             0.500000
# 2420520             0.833333             0.833333             1.000000
#
# [2420521 rows x 1223 columns]

# %%
file = open(f'{current_round}_report.txt', 'w', encoding="utf-8")

def objective(trial):
    param = {
            'tree_method':'hist',  #this parameter means using the GPU when training our model to speedup the training process
            'n_estimators': trial.suggest_categorical('n_estimators', [300, 700, 1500]),
            'objective': trial.suggest_categorical('objective', ['reg:squarederror']),
            'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0, 5),
            'gamma': trial.suggest_float('gamma', 0, 5),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.0, 1.0),
            'subsample': trial.suggest_float('subsample', 0.0, 1.0),
            'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1),
            'max_depth': trial.suggest_int('max_depth', 3, 5),
            'random_state': trial.suggest_categorical('random_state', [2020]),
            'min_child_weight': trial.suggest_int('min_child_weight', 10, 300),
            'eval_metric': trial.suggest_categorical('eval_metric', ['mae'])
        }
    
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, 'validation_0-mae')
    model = xgb.XGBRegressor(**param)  
    
    model.fit(training_data.filter(like='feature_', axis='columns'), training_data[TARGET_COL], eval_set=[(validation_data.filter(like='feature_', axis='columns'), validation_data[TARGET_COL])], early_stopping_rounds=20, callbacks=[pruning_callback])
    
    preds = model.predict(validation_data.filter(like='feature_', axis='columns'))
    
    mae = mean_absolute_error(validation_data[TARGET_COL], preds)
    
    return mae

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100, show_progress_bar=True)
print_both(file, 'Number of finished trials:', len(study.trials))
print_both(file, 'Best trial:', study.best_trial.params)

gc.collect()
# Out:
# [I 2022-11-23 14:55:30,105] A new study created in memory with name: no-name-e07e8000-9bfa-480e-853f-f6d8fe607372
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\progress_bar.py:49: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/100 [00:59<?, ?it/s]
# [W 2022-11-23 14:56:29,632] Trial 0 failed because of the following error: XGBoostError('[14:56:29] C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/data/data.cc:487: Check failed: valid: Label contains NaN, infinity or a value too large.')
# Traceback (most recent call last):
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_18796\4087210166.py", line 23, in objective
#     model.fit(training_data.filter(like='feature_', axis='columns'), training_data[TARGET_COL], eval_set=[(validation_data.filter(like='feature_', axis='columns'), validation_data[TARGET_COL])], early_stopping_rounds=20, callbacks=[pruning_callback])
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 532, in inner_f
#     return f(**kwargs)
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 931, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 449, in _wrap_evaluation_matrices
#     m = create_dmatrix(
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 945, in <lambda>
#     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 532, in inner_f
#     return f(**kwargs)
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 654, in __init__
#     self.set_info(
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 532, in inner_f
#     return f(**kwargs)
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 719, in set_info
#     self.set_label(label)
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 850, in set_label
#     dispatch_meta_backend(self, label, 'label', 'float')
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py", line 1043, in dispatch_meta_backend
#     _meta_from_pandas_series(data, name, dtype, handle)
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py", line 368, in _meta_from_pandas_series
#     _meta_from_numpy(data, name, dtype, handle)
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py", line 976, in _meta_from_numpy
#     _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#   File "c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 203, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [14:56:29] C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/data/data.cc:487: Check failed: valid: Label contains NaN, infinity or a value too large.
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# c:\Users\PC\Documents\Github\numerai_research\research.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> study = optuna.create_study(direction='minimize')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> study.optimize(objective, n_trials=100, show_progress_bar=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> print_both(file, 'Number of finished trials:', len(study.trials))
#       <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> print_both(file, 'Best trial:', study.best_trial.params)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\study.py:419, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     315 def optimize(
#     316     self,
#     317     func: ObjectiveFuncType,
#    (...)
#     324     show_progress_bar: bool = False,
#     325 ) -> None:
#     326     """Optimize an objective function.
#     327
#     328     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     416             If nested invocation of this method occurs.
#     417     """
# --> 419     _optimize(
#     420         study=self,
#     421         func=func,
#     422         n_trials=n_trials,
#     423         timeout=timeout,
#     424         n_jobs=n_jobs,
#     425         catch=catch,
#     426         callbacks=callbacks,
#     427         gc_after_trial=gc_after_trial,
#     428         show_progress_bar=show_progress_bar,
#     429     )
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as CircleCI).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:234, in _run_trial(study, func, catch)
#     227         assert False, "Should not reach."
#     229 if (
#     230     frozen_trial.state == TrialState.FAIL
#     231     and func_err is not None
#     232     and not isinstance(func_err, catch)
#     233 ):
# --> 234     raise func_err
#     235 return frozen_trial
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\optuna\study\_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# c:\Users\PC\Documents\Github\numerai_research\research.ipynb Cell 12 in objective(trial)
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a> pruning_callback = optuna.integration.XGBoostPruningCallback(trial, 'validation_0-mae')
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=20'>21</a> model = xgb.XGBRegressor(**param)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a> model.fit(training_data.filter(like='feature_', axis='columns'), training_data[TARGET_COL], eval_set=[(validation_data.filter(like='feature_', axis='columns'), validation_data[TARGET_COL])], early_stopping_rounds=20, callbacks=[pruning_callback])
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=24'>25</a> preds = model.predict(validation_data.filter(like='feature_', axis='columns'))
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Documents/Github/numerai_research/research.ipynb#X14sZmlsZQ%3D%3D?line=26'>27</a> mae = mean_absolute_error(validation_data[TARGET_COL], preds)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:931, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     880 """Fit gradient boosting model.
#     881
#     882 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     928         Use `callbacks` in :py:meth:`__init__` or :py:meth:`set_params` instead.
#     929 """
#     930 evals_result: TrainingCallback.EvalsLog = {}
# --> 931 train_dmatrix, evals = _wrap_evaluation_matrices(
#     932     missing=self.missing,
#     933     X=X,
#     934     y=y,
#     935     group=None,
#     936     qid=None,
#     937     sample_weight=sample_weight,
#     938     base_margin=base_margin,
#     939     feature_weights=feature_weights,
#     940     eval_set=eval_set,
#     941     sample_weight_eval_set=sample_weight_eval_set,
#     942     base_margin_eval_set=base_margin_eval_set,
#     943     eval_group=None,
#     944     eval_qid=None,
#     945     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     946     enable_categorical=self.enable_categorical,
#     947 )
#     948 params = self.get_xgb_params()
#     950 if callable(self.objective):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:449, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical)
#     447         evals.append(train_dmatrix)
#     448     else:
# --> 449         m = create_dmatrix(
#     450             data=valid_X,
#     451             label=valid_y,
#     452             weight=sample_weight_eval_set[i],
#     453             group=eval_group[i],
#     454             qid=eval_qid[i],
#     455             base_margin=base_margin_eval_set[i],
#     456             missing=missing,
#     457             enable_categorical=enable_categorical,
#     458         )
#     459         evals.append(m)
#     460 nevals = len(evals)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:945, in XGBModel.fit.<locals>.<lambda>(**kwargs)
#     880 """Fit gradient boosting model.
#     881
#     882 Note that calling ``fit()`` multiple times will cause the model object to be
#    (...)
#     928         Use `callbacks` in :py:meth:`__init__` or :py:meth:`set_params` instead.
#     929 """
#     930 evals_result: TrainingCallback.EvalsLog = {}
#     931 train_dmatrix, evals = _wrap_evaluation_matrices(
#     932     missing=self.missing,
#     933     X=X,
#     934     y=y,
#     935     group=None,
#     936     qid=None,
#     937     sample_weight=sample_weight,
#     938     base_margin=base_margin,
#     939     feature_weights=feature_weights,
#     940     eval_set=eval_set,
#     941     sample_weight_eval_set=sample_weight_eval_set,
#     942     base_margin_eval_set=base_margin_eval_set,
#     943     eval_group=None,
#     944     eval_qid=None,
# --> 945     create_dmatrix=lambda **kwargs: DMatrix(nthread=self.n_jobs, **kwargs),
#     946     enable_categorical=self.enable_categorical,
#     947 )
#     948 params = self.get_xgb_params()
#     950 if callable(self.objective):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:654, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     651 assert handle is not None
#     652 self.handle = handle
# --> 654 self.set_info(
#     655     label=label,
#     656     weight=weight,
#     657     base_margin=base_margin,
#     658     group=group,
#     659     qid=qid,
#     660     label_lower_bound=label_lower_bound,
#     661     label_upper_bound=label_upper_bound,
#     662     feature_weights=feature_weights,
#     663 )
#     665 if feature_names is not None:
#     666     self.feature_names = feature_names
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:532, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#     530 for k, arg in zip(sig.parameters, args):
#     531     kwargs[k] = arg
# --> 532 return f(**kwargs)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:719, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     716 from .data import dispatch_meta_backend
#     718 if label is not None:
# --> 719     self.set_label(label)
#     720 if weight is not None:
#     721     self.set_weight(weight)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:850, in DMatrix.set_label(self, label)
#     842 """Set label of dmatrix
#     843
#     844 Parameters
#    (...)
#     847     The label information to be set into DMatrix
#     848 """
#     849 from .data import dispatch_meta_backend
# --> 850 dispatch_meta_backend(self, label, 'label', 'float')
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:1043, in dispatch_meta_backend(matrix, data, name, dtype)
#    1041     return
#    1042 if _is_pandas_series(data):
# -> 1043     _meta_from_pandas_series(data, name, dtype, handle)
#    1044     return
#    1045 if _is_dlpack(data):
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:368, in _meta_from_pandas_series(data, name, dtype, handle)
#     366     data = data.to_dense()
#     367 assert len(data.shape) == 1 or data.shape[1] == 0 or data.shape[1] == 1
# --> 368 _meta_from_numpy(data, name, dtype, handle)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:976, in _meta_from_numpy(data, field, dtype, handle)
#     974     raise ValueError("Masked array is not supported.")
#     975 interface_str = _array_interface(data)
# --> 976 _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:203, in _check_call(ret)
#     192 """Check the return value of C API call
#     193
#     194 This function will raise exception when error occurs.
#    (...)
#     200     return value from API calls
#     201 """
#     202 if ret != 0:
# --> 203     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [14:56:29] C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/data/data.cc:487: Check failed: valid: Label contains NaN, infinity or a value too large.

# %%
gc.collect()
    
X = df.drop(targets, axis=1)
y = df[target]


if os.path.exists(f'../models/best_trial_{project}_{ticker}.parquet'):
    trial = study.trials_dataframe()
    trial_best_score = trial['value'].min()

    historic_best_studies = pd.read_parquet(f'../models/best_trial_{project}_{ticker}.parquet')
    historic_best_score = historic_best_studies['value'].min()

    if trial_best_score > historic_best_score:
        print_both(file, f'- Current best score: {trial_best_score} is no improvement over historic best score: {historic_best_score}, do nothing')
        
    else:
        print_both(file, f'- Current best score: {trial_best_score} is an improvement over historic best score: {historic_best_score}, update best trial')
        trial.to_parquet(f'../models/best_trial_{project}_{ticker}.parquet')
        print_both(file, f'- Data saved to ../models/best_trial_{project}_{ticker}.parquet')
        
        best_trial = study.best_trial.params
        best_trial['tree_method'] = 'hist'

        model = xgb.XGBRegressor(**best_trial)
        model.fit(X, y)

        preds = model.predict(X)

        print_both(file, f"MAE for set: {mean_absolute_error(y, preds)}")
        print_both(file, f"R2 for set: {r2_score(y, preds)}")
        joblib.dump(model, f'../models/{project}_{ticker}_predictor.joblib')
else:
    trial = study.trials_dataframe()
    trial.to_parquet(f'../models/best_trial_{project}_{ticker}.parquet')
    best_trial = study.best_trial.params
    best_trial['tree_method'] = 'hist'

    model = xgb.XGBRegressor(**best_trial)
    model.fit(X, y)

    preds = model.predict(X)

    print_both(file, f"MAE for set: {mean_absolute_error(y, preds)}")
    print_both(file, f"R2 for set: {r2_score(y, preds)}")
    joblib.dump(model, f'../models/{project}_{ticker}_predictor.joblib')

# %%
 
read_columns = features + [ERA_COL, DATA_TYPE_COL, TARGET_COL]

# note: sometimes when trying to read the downloaded data you get an error about invalid magic parquet bytes...
# if so, delete the file and rerun the napi.download_dataset to fix the corrupted file
training_data = pd.read_parquet('v4/train.parquet',
                                columns=read_columns)
validation_data = pd.read_parquet('v4/validation.parquet',
                                  columns=read_columns)
live_data = pd.read_parquet(f'v4/live_{current_round}.parquet',
                                  columns=read_columns)
